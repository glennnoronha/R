# %% [markdown]
# <a href="https://colab.research.google.com/github/glennnoronha/R/blob/main/data_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.6
# ✔ forcats   1.0.1     ✔ stringr   1.6.0
# ✔ ggplot2   4.0.1     ✔ tibble    3.3.0
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.2.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
install.packages('palmerpenguins')
library(palmerpenguins)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
#
# Attaching package: ‘palmerpenguins’
#
#
# The following objects are masked from ‘package:datasets’:
#
#     penguins, penguins_raw

# %% [markdown]
# use glimpse() to get information of all columns, and some values <br>
# similar to str() but shows more info

# %%
?glimpse
glimpse(penguins)
?penguins
# Out:
# Rows: 344
# Columns: 8
# $ species           <fct> Adelie, Adelie, Adelie, Adelie, Adelie, Adelie, Adel…
# $ island            <fct> Torgersen, Torgersen, Torgersen, Torgersen, Torgerse…
# $ bill_length_mm    <dbl> 39.1, 39.5, 40.3, NA, 36.7, 39.3, 38.9, 39.2, 34.1, …
# $ bill_depth_mm     <dbl> 18.7, 17.4, 18.0, NA, 19.3, 20.6, 17.8, 19.6, 18.1, …
# $ flipper_length_mm <int> 181, 186, 195, NA, 193, 190, 181, 195, 193, 190, 186…
# $ body_mass_g       <int> 3750, 3800, 3250, NA, 3450, 3650, 3625, 4675, 3475, …
# $ sex               <fct> male, female, female, NA, female, male, female, male…
# $ year              <int> 2007, 2007, 2007, 2007, 2007, 2007, 2007, 2007, 2007…

# %% [markdown]
# ### Scatter Plot

# %% [markdown]
# aes() defines how data maps to axes
# <br>
# geom_point() draws the points using that mapping

# %%
?aes
ggplot(
  data = penguins,
  mapping = aes(x=flipper_length_mm,y=body_mass_g)
  ) +
    geom_point()
# Out:
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %% [markdown]
# using color to differentiate between species

# %%
ggplot(
  data=penguins,
  mapping=aes(x=flipper_length_mm,y=body_mass_g,color=species)
) +
  geom_point()
# Out:
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %% [markdown]
# adding a line of best fit using linear model method

# %%
ggplot(
  data=penguins,
  mapping=aes(x=flipper_length_mm,y=body_mass_g,color=species)
) +
  geom_point() +
  geom_smooth(method="lm")
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range (`stat_smooth()`).”
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %% [markdown]
# adding color only to the points themselves

# %%
ggplot(
  penguins,
  aes(x=flipper_length_mm,y=body_mass_g)
) +
  geom_point(aes(color=species)) +
  geom_smooth(method = "lm")
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range (`stat_smooth()`).”
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %% [markdown]
# Adding a different shape for each species

# %%
ggplot(
  penguins,
  aes(x=flipper_length_mm,y=body_mass_g)
) +
  geom_point(aes(color=species, shape=species)) +
  geom_smooth(method = "lm")
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range (`stat_smooth()`).”
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %% [markdown]
# Editting the labels to whatver we desire

# %%
ggplot(
  penguins,
  aes(x=flipper_length_mm,y=body_mass_g)
) +
  geom_point(aes(color=species, shape=species)) +
  geom_smooth(method = "lm") +
  labs(
    title = "Body Mass (g) vs Flipper Length (mm)",
    subtitle = "Measurements for Adelie, Chinstrap and Gentoo Penguins",
    x = "Flipper Length (mm)", y = "Body Mass (g)",
    color = "Species", shape = "Species",
    caption="Data come from the palmerpenguins package"
  )
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range (`stat_smooth()`).”
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %% [markdown]
# Recreating the same plot with piping

# %%
penguins %>%
  ggplot(aes(x=flipper_length_mm,y=body_mass_g)) +
  geom_point(aes(color=species, shape=species)) +
  geom_smooth(method = "lm") +
  labs(
    title = "Body Mass (g) vs Flipper Length (mm)",
    subtitle = "Measurements for Adelie, Chinstrap and Gentoo Penguins",
    x = "Flipper Length (mm)", y = "Body Mass (g)",
    color = "Species", shape = "Species",
    caption="Data come from the palmerpenguins package"
  )
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range (`stat_smooth()`).”
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %% [markdown]
# There are 344 rows and 8 columns in this data set

# %%
glimpse(penguins)
# Out:
# Rows: 344
# Columns: 8
# $ species           <fct> Adelie, Adelie, Adelie, Adelie, Adelie, Adelie, Adel…
# $ island            <fct> Torgersen, Torgersen, Torgersen, Torgersen, Torgerse…
# $ bill_length_mm    <dbl> 39.1, 39.5, 40.3, NA, 36.7, 39.3, 38.9, 39.2, 34.1, …
# $ bill_depth_mm     <dbl> 18.7, 17.4, 18.0, NA, 19.3, 20.6, 17.8, 19.6, 18.1, …
# $ flipper_length_mm <int> 181, 186, 195, NA, 193, 190, 181, 195, 193, 190, 186…
# $ body_mass_g       <int> 3750, 3800, 3250, NA, 3450, 3650, 3625, 4675, 3475, …
# $ sex               <fct> male, female, female, NA, female, male, female, male…
# $ year              <int> 2007, 2007, 2007, 2007, 2007, 2007, 2007, 2007, 2007…

# %%
ggplot(
  penguins,
  aes(x=bill_length_mm, y=bill_depth_mm)
) +
  geom_point(aes(color=species, shape=sex)) +
  geom_smooth(method="lm")
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range (`stat_smooth()`).”
# Warning message:
# “Removed 11 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %% [markdown]
# Recreating the plot from earlier but using color brightness to showcase bill_depth_mm

# %%
ggplot(
  penguins,
  aes(x=flipper_length_mm, y=body_mass_g)
) +
  geom_point(aes(color=bill_depth_mm)) +
  geom_smooth(method="gam")

 ?geom_smooth
# Out:
# `geom_smooth()` using formula = 'y ~ s(x, bs = "cs")'
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range (`stat_smooth()`).”
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %% [markdown]
# se=FALSE removes the display of the confidence band

# %%
install.packages('patchwork')
library(patchwork)
p1 <- ggplot(
  data = penguins,
  mapping = aes(x = flipper_length_mm, y = body_mass_g, color = island)
) +
  geom_point() +
  geom_smooth()

p2 <- ggplot(
  data = penguins,
  mapping = aes(x = flipper_length_mm, y = body_mass_g, color = island)
) +
  geom_point() +
  geom_smooth(se = FALSE)

p1 + p2
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range (`stat_smooth()`).”
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range (`stat_smooth()`).”
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %% [markdown]
# ### Bar Graph

# %% [markdown]
# geom_bar() creates a bar graph

# %%
penguins %>%
  ggplot(aes(x = species)) +
  geom_bar()
# Out:
# plot without title

# %% [markdown]
# Order the bars based on frequency from highest to lowest

# %%
penguins %>%
  ggplot(aes(x = fct_infreq(species))) +
  geom_bar()
# Out:
# plot without title

# %% [markdown]
# on the y-axis instead

# %%
penguins %>%
  ggplot(aes(y = fct_infreq(species))) +
  geom_bar()
# Out:
# plot without title

# %% [markdown]
# Differences between color and fill for bar charts <br>
#
# fill is better for bar charts

# %%
color_bar <- ggplot(penguins, aes(x = species)) +
  geom_bar(color = "red")

fill_bar <- ggplot(penguins, aes(x = species)) +
  geom_bar(fill = "red")

color_bar + fill_bar
# Out:
# plot without title

# %% [markdown]
# ### Histogram

# %% [markdown]
# use bin width to divide the bins by a custom amount. Here we do 200 g

# %%
penguins %>%
  ggplot(aes(x = body_mass_g)) +
  geom_histogram(na.rm = TRUE, binwidth = 200)
# Out:
# plot without title

# %% [markdown]
# ### Density Plot

# %%
penguins %>%
  ggplot(aes(x=body_mass_g)) +
  geom_density()
# Out:
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range
# (`stat_density()`).”
# plot without title

# %% [markdown]
# ### Diamonds Data Set

# %%
glimpse(diamonds)
# Out:
# Rows: 53,940
# Columns: 10
# $ carat   <dbl> 0.23, 0.21, 0.23, 0.29, 0.31, 0.24, 0.24, 0.26, 0.22, 0.23, 0.…
# $ cut     <ord> Ideal, Premium, Good, Premium, Good, Very Good, Very Good, Ver…
# $ color   <ord> E, E, E, I, J, J, I, H, E, H, J, J, F, J, E, E, I, J, J, J, I,…
# $ clarity <ord> SI2, SI1, VS1, VS2, SI2, VVS2, VVS1, SI1, VS2, VS1, SI1, VS1, …
# $ depth   <dbl> 61.5, 59.8, 56.9, 62.4, 63.3, 62.8, 62.3, 61.9, 65.1, 59.4, 64…
# $ table   <dbl> 55, 61, 65, 58, 58, 57, 57, 55, 61, 61, 55, 56, 61, 54, 62, 58…
# $ price   <int> 326, 326, 327, 334, 335, 336, 336, 337, 337, 338, 339, 340, 34…
# $ x       <dbl> 3.95, 3.89, 4.05, 4.20, 4.34, 3.94, 3.95, 4.07, 3.87, 4.00, 4.…
# $ y       <dbl> 3.98, 3.84, 4.07, 4.23, 4.35, 3.96, 3.98, 4.11, 3.78, 4.05, 4.…
# $ z       <dbl> 2.43, 2.31, 2.31, 2.63, 2.75, 2.48, 2.47, 2.53, 2.49, 2.39, 2.…

# %%
diamonds %>%
  ggplot(aes(x=carat)) +
  geom_histogram(binwidth=0.05)
# Out:
# plot without title

# %% [markdown]
# ### Visualizing Relationships

# %% [markdown]
# A numerical and categorical variable

# %%
penguins %>%
  ggplot(aes(x=species, y=body_mass_g)) +
  geom_boxplot()
# Out:
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range
# (`stat_boxplot()`).”
# plot without title

# %%
penguins %>%
  ggplot(aes(x = body_mass_g, color = species, fill=species)) +
  geom_density(alpha=0.5)
# Out:
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range
# (`stat_density()`).”
# plot without title

# %% [markdown]
# Two categorical variables

# %%
penguins %>%
  ggplot(aes(x=island, fill=species)) +
  geom_bar()
# Out:
# plot without title

# %% [markdown]
# shows the percentage of each species on each island

# %%
penguins %>%
  ggplot(aes(x=island, fill=species)) +
  geom_bar(position="fill") +
  labs(title = "Species Composition by Island",y="Percentage", fill = "Species", x = "Island")
# Out:
# plot without title

# %% [markdown]
# two numerical values (typically scatter plot)

# %% [markdown]
# 3 or more variables <br>
# to many mappings on one plot can get cluttered so you can use facets / subplots to display the data cleaner
# the variable that is passed into facet_wrap should be caterogical

# %%
penguins %>%
  ggplot(aes(x=flipper_length_mm,y=body_mass_g)) +
  geom_point(aes(color=species, shape=species)) +
  facet_wrap(~island)
# Out:
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %%
glimpse(mpg)
?mpg
# Out:
# Rows: 234
# Columns: 11
# $ manufacturer <chr> "audi", "audi", "audi", "audi", "audi", "audi", "audi", "…
# $ model        <chr> "a4", "a4", "a4", "a4", "a4", "a4", "a4", "a4 quattro", "…
# $ displ        <dbl> 1.8, 1.8, 2.0, 2.0, 2.8, 2.8, 3.1, 1.8, 1.8, 2.0, 2.0, 2.…
# $ year         <int> 1999, 1999, 2008, 2008, 1999, 1999, 2008, 1999, 1999, 200…
# $ cyl          <int> 4, 4, 4, 4, 6, 6, 6, 4, 4, 4, 4, 6, 6, 6, 6, 6, 6, 8, 8, …
# $ trans        <chr> "auto(l5)", "manual(m5)", "manual(m6)", "auto(av)", "auto…
# $ drv          <chr> "f", "f", "f", "f", "f", "f", "f", "4", "4", "4", "4", "4…
# $ cty          <int> 18, 21, 20, 21, 16, 18, 18, 18, 16, 20, 19, 15, 17, 17, 1…
# $ hwy          <int> 29, 29, 31, 30, 26, 26, 27, 26, 25, 28, 27, 25, 25, 25, 2…
# $ fl           <chr> "p", "p", "p", "p", "p", "p", "p", "p", "p", "p", "p", "p…
# $ class        <chr> "compact", "compact", "compact", "compact", "compact", "c…

# %%
mpg %>%
  ggplot(aes(x=hwy,y=cty)) +
  geom_point()+
  geom_smooth(method=lm)
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %%
penguins %>%
  ggplot(aes(bill_depth_mm,bill_length_mm)) +
  geom_point(aes(color=species)) +
  facet_wrap(~species)
# Out:
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %%
ggplot(
  data = penguins,
  mapping = aes(
    x = bill_length_mm, y = bill_depth_mm,
    color = species, shape = species
  )
) +
  geom_point() +
  labs(color = "Species", shape="Species")
# Out:
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %%
ggplot(penguins, aes(x = island, fill = species)) +
  geom_bar(position = "fill")
ggplot(penguins, aes(x = species, fill = island)) +
  geom_bar(position = "fill")
# Out:
# plot without title
# plot without title

# %% [markdown]
# The first plot displays the proportion of species in each island.<br>
# The second plot displays the proportion of islands each species lives in

# %% [markdown]
# ### Saving a plot

# %%
penguins %>%
  ggplot(aes(flipper_length_mm,body_mass_g)) +
  geom_point(na.rm=TRUE, aes(color=species))
  ggsave(filename="test-save-splot.png")
# Out:
# Saving 6.67 x 6.67 in image
# plot without title

# %% [markdown]
# ggsave() saves the last plot that is displayed

# %%
ggplot(mpg, aes(x = class)) +
  geom_bar()
ggplot(mpg, aes(x = cty, y = hwy)) +
  geom_point()
ggsave("mpg-plot.png")
# Out:
# plot without title
# Saving 6.67 x 6.67 in image
# plot without title
